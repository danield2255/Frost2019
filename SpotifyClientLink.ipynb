# %% [markdown]
# ## Get Albums and Artist Info from Spotify

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import json
import re
import pandas as pd
import numpy as np

#Spotify credentials to be able to access the spotify API and ultimately access their data
clientId = #Input own
clientSecret = #Input own 
clientCredentialsManager = SpotifyClientCredentials(client_id=clientId, client_secret=clientSecret)
sp = spotipy.Spotify(client_credentials_manager=clientCredentialsManager) #spotify object to access API

def spotifyArtistInfo(artist):
    result = sp.search(artist,type='artist') #search query
    artist = result['artists']['items'][0]
    followers = artist['followers']['total']
    genres = artist['genres']
    return (followers, genres)

def spotifyArtistAblums(artist):
    search = sp.search(q='artist:' + artist, type='artist')
    artist = search['artists']['items'][0]
    albums = []
    search = sp.artist_albums(artist['id'], album_type='album')
    albums.extend(search['items'])
    while search['next']:
        search = sp.next(search)
        albums.extend(search['items'])
    studioAlbums = []
    allAlbums = []
    albumNames = set()
    albums.sort(key=lambda album:album['name'].lower())
    firstAlbYear = 3000 #Arbitrarilly large
    for album in albums:
        name = album['name']
        albumId = album['id']
        year = int(album['release_date'][0:4])
        if year < firstAlbYear:
            firstAlbYear = year
        type_ = album['album_group']
        #If there is an album that has a deluxe version, the deluxe one will be selected
        exclude = ["spotify sessions", " live in ", " live from ","live at ", "(live)", " live version", "live lounge", "tour live", "stadium tour","radio release", "karaoke","extended edition", "commentary", " tour edition", "remix album", "standard version", "international edition","international version", "international deluxe", "anniversary edition", "special edition", " case version", "bonus version", "asia deluxe", "japan deluxe", "china version", "japan version", "uk version","canada version", "int'l version","(international", "international)", "live north america", 'north america live', "live at the bbc", "soundtrack", "radio release"]
        if name not in albumNames and not any(x in name.lower() for x in exclude) and type_ == 'album':
            albumNames.add(name)
            allAlbums.append((name, album))
    notDeluxe = []
    deluxeVersion = []
    unDeluxed = []
    terms = ["(deluxe)", "(deluxe edition)", "(deluxe version)", " deluxe edition", " deluxe version", "deluxe"]
    for a in allAlbums:
        if "deluxe" in a[0].lower():
            deluxeVersion.append(a)
            studioAlbums.append(a[1])
            deluxeName = a[0].lower()
            for term in terms:
                deluxeName = deluxeName.replace(term, "")
            unDeluxed.append(deluxeName)
        else:
            notDeluxe.append(a)
    for item in notDeluxe:
        #print(unDeluxed)
        if not any(d.strip().lower() == item[0].strip().lower() for d in unDeluxed):
            studioAlbums.append(item[1])
    for i in studioAlbums:
        #Toggle this on to print
        #print(i["name"])
        pass
    return (studioAlbums, firstAlbYear)

# %%
albs, firstYear = spotifyArtistAblums("Maroon 5")
# Out:
# Hands All Over (Deluxe)
# Overexposed (Deluxe)
# Red Pill Blues (Deluxe)
# Red Pill Blues + (Deluxe)
# V (Deluxe)
# 1.22.03 Acoustic
# It Won't Be Soon Before Long
# It Won't Be Soon Before Long.
# Live Friday The 13th
# Overexposed Track By Track
# Songs About Jane

# %% [markdown]
# ## Run Qualifier Check for All Billboard Artists

# %% [markdown]
# An artist qualifies for consideration in the study if:
# - they have content which has appeared on the Billboard Hot 100 in the last 20 years
# - they they have at least 3 albums released
# - their first album was released at least 7 years ago
#
# The billboard scraper goes back 1043 weeks (20 years) to collect data, and then this script will use spotify to ultimately see if the artist qualifies.

# %%
#Currently doesn't catch destiny's child
dataPre = pd.DataFrame(pd.read_csv('FrostData/Weekly_data_clean.csv'))
artistData = pd.DataFrame(columns = ["Artist", 'Followers', "Genres", "NumAlbums", "YearFirstAlbum"])
drops = []
outArtists = []
for index, row in dataPre.iterrows():
    artists = row["Artists"].split(",")
    ##Some special cases
    if artists == ['Machine Gun Kelly', '', ' Ambassadors', ' Bebe Rexha']:
        artists = ['Machine Gun Kelly', 'X Ambassadors', ' Bebe Rexha']
    elif artists == ['Pusha T Kanye West']:
        artists = ["Pusha T", "Kanye West"]
    elif artists == ['Jay Z Kanye West']:
        artists = ['Jay Z', "Kanye West"]
    elif 'Tyler' in artists and ' The Creator' in artists:
        artists.remove("Tyler")
        artists.remove(" The Creator")
        artists.append("Tyler The Creator")
    elif " Swae Lee Or Rae Sremmurd" in artists:
        artists = ["Swae Lee", "Rae Sremmurd"]
    elif "Plies Or OJ Da Juiceman" in artists:
        artists = ['Plies', 'OJ Da Juiceman']
    if all(a.strip() in (artistData['Artist'].tolist() + outArtists) for a in artists):
        for a in artists:
            if a.strip() in outArtists:
                drops.append(index)
        continue
    else:
        for a in artists:
            artist = a.strip().replace(" &", "")
            if " + " in artist and artist !=  "Dan + Shay":
                new = artist.split("+")
                artists.extend(new)
                continue
            elif " with " in artist:
                new = artist.split(' with ')
                artists.extend(new)
                continue
            elif " With " in artist:
                new = artist.split(' With ')
                artists.extend(new)
                continue
            if artist in outArtists:
                drops.append(index)
                continue
            if artist not in artistData['Artist'].tolist():
                print(str(index) + " ARTIST : " + artist)
                try:
                    albums, firstYear= spotifyArtistAblums(artist)
                except: 
                    #Add to this as we find
                    transferArtists = {"DU DDU":"BLACKPINK", "NBA YoungBoy":"YoungBoy Never Broke Again","Maejor Ali":"Maejor", "ROCKMAFIA":"rock mafia", "Soulja Boy Tell'em":"Soulja Boy", "Ludacris Co":"Ludacris", "Purple Ribbon All":"Purple Ribbon All-Stars", "Fat Man Scoop":"Fatman Scoop", "The Clark Family Experience":"Clark Family Experience", "SoulDecision":"Soul Decision", "Travi$ Scott": "Travis Scott" }
                    if artist in list(transferArtists.keys()):
                        artist = transferArtists[artist]
                    try:
                        albums, firstYear= spotifyArtistAblums(artist)
                    except:
                        print("Not actually a spotify artist!")
                        continue
                if len(albums) >= 3 and firstYear < 2012: #then they qualify, and collect the artist data
                    followers, genres = spotifyArtistInfo(artist)
                    artistData = artistData.append({"Artist": artist, 'Followers':followers, "Genres": ",".join(genres), "NumAlbums":len(albums), "YearFirstAlbum": firstYear}, ignore_index = True) 
                else:
                    outArtists.append(artist)
                    drops.append(index)
        
dataPost = dataPre.drop(drops)
dataPost.to_csv("FrostData/billboardRankings.csv")
artistData.to_csv("FrostData/artistInfo.csv")
# Out:
# 0 ARTIST : Lil Nas
# 0 ARTIST :
# Not actually a spotify artist!
# 1 ARTIST : Shawn Mendes
# 1 ARTIST : Camila Cabello
# 2 ARTIST : Billie Eilish
# 3 ARTIST : Khalid
# 4 ARTIST : Ed Sheeran
# 4 ARTIST : Justin Bieber
# 5 ARTIST : Jonas Brothers
# 6 ARTIST : DaBaby
# 7 ARTIST : Drake
# 8 ARTIST : Chris Brown
# 9 ARTIST : Post Malone
# 10 ARTIST : Lizzo
# 11 ARTIST : Swae Lee
# 12 ARTIST : Taylor Swift
# 14 ARTIST : Sam Smith
# 14 ARTIST : Normani
# 15 ARTIST : Lil Nas X
# 16 ARTIST : Halsey
# 17 ARTIST : Blake Shelton
# 18 ARTIST : Polo G
# 19 ARTIST : Nicki Minaj
# 20 ARTIST : Ava Max
# 21 ARTIST : Cardi B
# 22 ARTIST : Ariana Grande
# 23 ARTIST : Panic! At The Disco
# 24 ARTIST : Marshmello
# 24 ARTIST : Bastille
# 25 ARTIST : Lee Brice
# 26 ARTIST : Katy Perry
# 27 ARTIST : Morgan Wallen
# 28 ARTIST : Blanco Brown
# 29 ARTIST : Young Thug
# 29 ARTIST : J. Cole
# 29 ARTIST : Travis Scott
# 32 ARTIST : Luke Combs
# 33 ARTIST : City Girls
# 34 ARTIST : benny blanco
# 36 ARTIST : Daddy Yankee
# 37 ARTIST : Mustard
# 37 ARTIST : Migos
# 39 ARTIST : Meek Mill
# 41 ARTIST : Lady Gaga
# 41 ARTIST : Bradley Cooper
# 43 ARTIST : Dan + Shay
# 45 ARTIST : Tyler The Creator
# 46 ARTIST : A Boogie Wit da Hoodie
# 47 ARTIST : NLE Choppa
# 50 ARTIST : YG
# 50 ARTIST : Tyga
# 50 ARTIST : Jon Z
# 51 ARTIST : Lewis Capaldi
# 52 ARTIST : Thomas Rhett
# 54 ARTIST : Offset
# 55 ARTIST : Kane Brown
# 57 ARTIST : YK Osiris
# 58 ARTIST : DJ Khaled
# 59 ARTIST : Luke Bryan
# 60 ARTIST : P!nk
# 61 ARTIST : Maren Morris
# 62 ARTIST : 5 Seconds Of Summer
# 63 ARTIST : Bruno Mars
# 64 ARTIST : Eric Church
# 66 ARTIST : Bad Bunny
# 66 ARTIST : Tainy
# 68 ARTIST : Ali Gatie
# 69 ARTIST : Jason Aldean
# 70 ARTIST : Lil Baby
# 71 ARTIST : The Chainsmokers
# 71 ARTIST : Bebe Rexha
# 72 ARTIST : Summer Walker
# 73 ARTIST : Lunay
# 74 ARTIST : Florida Georgia Line
# 75 ARTIST : SHAED
# 76 ARTIST : Yella Beezy
# 76 ARTIST : Gucci Mane
# 76 ARTIST : Quavo
# 77 ARTIST : Beyonce
# 79 ARTIST : Chris Young
# 81 ARTIST : Sech
# 82 ARTIST : Chase Rice
# 83 ARTIST : Bryce Vine
# 86 ARTIST : Brett Eldredge
# 87 ARTIST : Lil Uzi Vert
# 88 ARTIST : Eli Young Band
# 89 ARTIST : Pedro Capo
# 89 ARTIST : Farruko
# 91 ARTIST : Justin Moore
# 92 ARTIST : Megan Thee Stallion
# 93 ARTIST : NAV
# 95 ARTIST : Ozuna
# 95 ARTIST : J Balvin
# 95 ARTIST : Anuel AA
# 98 ARTIST : Martin Garrix
# 99 ARTIST :
# Not actually a spotify artist!
# 145 ARTIST : Calboy
# 167 ARTIST : Kelsea Ballerini
# 172 ARTIST : Dreamville
# 177 ARTIST : Joji
# 191 ARTIST : Nicky Jam
# 195 ARTIST : Juice WRLD
# 196 ARTIST : Nipsey Hussle
# 198 ARTIST :
# Not actually a spotify artist!
# 275 ARTIST : Yo Gotti
# 279 ARTIST : Avicii
# 283 ARTIST : Future
# 284 ARTIST : Cody Johnson
# 297 ARTIST :
# Not actually a spotify artist!
# 350 ARTIST : Miley Cyrus
# 365 ARTIST : YNW Melly
# 366 ARTIST : NF
# 375 ARTIST : Joyner Lucas
# 381 ARTIST : Logic
# 387 ARTIST : Trippie Redd
# 393 ARTIST : Jon Pardi
# 394 ARTIST :
# Not actually a spotify artist!
# 442 ARTIST : 21 Savage
# 443 ARTIST : Blueface
# 482 ARTIST : Mabel
# 483 ARTIST : Lil Dicky
# 488 ARTIST : Maluma
# 491 ARTIST : Bazzi
# 492 ARTIST : Jhene Aiko
# 493 ARTIST :
# Not actually a spotify artist!
# 527 ARTIST : Maroon 5
# 577 ARTIST : Lady Antebellum
# 589 ARTIST : Brett Young
# 592 ARTIST :
# Not actually a spotify artist!
# 635 ARTIST : Dean Lewis
# 637 ARTIST : Gunna
# 648 ARTIST : Pinkfong
# 670 ARTIST : Old Dominion
# 678 ARTIST : Ella Mai
# 679 ARTIST : Lauv
# 679 ARTIST : Troye Sivan
# 688 ARTIST : 2 Chainz
# 689 ARTIST : Roddy Ricch
# 691 ARTIST :
# Not actually a spotify artist!
# 733 ARTIST : Ellie Goulding
# 733 ARTIST : Diplo
# 735 ARTIST : Lauren Daigle
# 779 ARTIST : SZA
# 779 ARTIST : The Weeknd
# 780 ARTIST : PnB Rock
# 780 ARTIST : XXXTENTACION
# 784 ARTIST : Lil Peep
# 784 ARTIST : iLoveMakonnen
# 786 ARTIST : Karol G
# 789 ARTIST : Ski Mask The Slump God
# 790 ARTIST :
# Not actually a spotify artist!
# 855 ARTIST : ScHoolboy Q
# 887 ARTIST : BLACKPINK
# 888 ARTIST :
# Not actually a spotify artist!
# 971 ARTIST : Imagine Dragons
# 976 ARTIST : French Montana
# 980 ARTIST : Scotty McCreery
# 983 ARTIST : Alec Benjamin
# 985 ARTIST : Michael Ray
# 987 ARTIST :
# Not actually a spotify artist!
# 1051 ARTIST : Five Finger Death Punch
# 1068 ARTIST : FLETCHER
# 1082 ARTIST : Riley Green
# 1085 ARTIST :
# Not actually a spotify artist!
# 1152 ARTIST : Victoria Monet
# 1167 ARTIST : SAFE
# 1178 ARTIST : Aventura
# 1184 ARTIST :
# Not actually a spotify artist!
# 1232 ARTIST : Kodak Black
# 1274 ARTIST : Selena Gomez
# 1278 ARTIST : Chris Stapleton
# 1298 ARTIST :
# Not actually a spotify artist!
# 1331 ARTIST : DJ Snake
# 1348 ARTIST : Jake Owen
# 1362 ARTIST : Jordan Davis
# 1363 ARTIST : Rich The Kid
# 1365 ARTIST : Lil Skies
# 1383 ARTIST : Carrie Underwood
# 1415 ARTIST :
# Not actually a spotify artist!
# 1445 ARTIST : Iggy Azalea
# 1466 ARTIST : Romeo Santos
# 1534 ARTIST :
# Not actually a spotify artist!
# 1578 ARTIST : Kehlani
# 1628 ARTIST : Flipp Dinero
# 1630 ARTIST : Sheck Wes
# 1646 ARTIST : Midland
# 1665 ARTIST :
# Not actually a spotify artist!
# 1678 ARTIST : Lukas Graham
# 1730 ARTIST : Pardison Fontaine
# 1754 ARTIST : Lil Pump
# 1765 ARTIST : Mark Ronson
# 1775 ARTIST : John Mayer
# 1841 ARTIST : Gesaffelstein
# 1861 ARTIST : Loud Luxury
# 1865 ARTIST : Zedd
# 1876 ARTIST : Dustin Lynch
# 1951 ARTIST : Lil Wayne
# 1954 ARTIST : Dierks Bentley
# 1955 ARTIST : Jacquees
# 1964 ARTIST : Zara Larsson
# 1974 ARTIST : Tory Lanez
# 1976 ARTIST : Kacey Musgraves
# 2132 ARTIST : Jimmie Allen
# 2175 ARTIST : Russell Dickerson
# 2264 ARTIST : Silk City
# 2264 ARTIST : Dua Lipa
# 2272 ARTIST : Hikaru Utada
# 2272 ARTIST : Skrillex
# 2361 ARTIST : Metro Boomin
# 2363 ARTIST : YoungBoy Never Broke Again
# 2432 ARTIST : Kip Moore
# 2467 ARTIST : 6ix9ine
# 2471 ARTIST : Eminem
# 2510 ARTIST : Mitchell Tenpenny
# 2571 ARTIST : Mariah Carey
# 2576 ARTIST : Bobby Helms
# 2577 ARTIST : Brenda Lee
# 2578 ARTIST : Burl Ives
# 2579 ARTIST : Nat King Cole
# 2581 ARTIST : Andy Williams
# 2584 ARTIST : Nosed Reindeer
# 2592 ARTIST : Wham!
# 2593 ARTIST : The Ronettes
# 2595 ARTIST : Gene Autry
# 2596 ARTIST : Jose Feliciano
# 2599 ARTIST : Perry Como
# 2601 ARTIST : Bing Crosby
# 2606 ARTIST : Elvis Presley
# 2608 ARTIST : Darlene Love
# 2609 ARTIST : Kelly Clarkson
# 2610 ARTIST : Chuck Berry
# 2614 ARTIST : Frank Sinatra
# 2708 ARTIST : Paul McCartney
# 2803 ARTIST : lovelytheband
# 3044 ARTIST : Daniel Caesar
# 3048 ARTIST : Kanye West
# 3050 ARTIST : Lil Mosey
# 3101 ARTIST : Queen
# 3148 ARTIST : AJR
# 3245 ARTIST : Tiesto
# 3245 ARTIST : Dzeko
# 3312 ARTIST : TakeOff
# 3331 ARTIST : Calvin Harris
# 3374 ARTIST : Michael Jackson
# 3389 ARTIST : Grey
# 3420 ARTIST : Chris Janson
# 3430 ARTIST : Steve Aoki
# 3435 ARTIST : Cole Swindell
# 3528 ARTIST : Lil Yachty
# 3533 ARTIST : Weezer
# 3617 ARTIST : Queen Naija
# 3710 ARTIST : twenty one pilots
# 3715 ARTIST : Charlie Puth
# 3807 ARTIST : Machine Gun Kelly
# 3820 ARTIST : Avril Lavigne
# 3903 ARTIST : Dylan Scott
# 3914 ARTIST : Mac Miller
# 3915 ARTIST : Ty Dolla $ign
# 3915 ARTIST : 6LACK
# 3917 ARTIST : Kygo
# 3921 ARTIST : The Carters
# 3922 ARTIST : Wiz Khalifa
# 3923 ARTIST : Clean Bandit
# 3924 ARTIST : Manuel Turizo
# 4109 ARTIST : Childish Gambino
# 4178 ARTIST : Jessie Reyez
# 4206 ARTIST : G
# 4250 ARTIST : Anne
# 4257 ARTIST : Kenny Chesney
# 4296 ARTIST : Elley Duhe
# 4297 ARTIST : Ciara
# 4300 ARTIST : Backstreet Boys
# 4390 ARTIST : Morgan Evans
# 4392 ARTIST : Janet
# 4396 ARTIST : Alessia Cara
# 4397 ARTIST : Chris Lane
# 4402 ARTIST : Li
# 4487 ARTIST : Jason Mraz
# 4493 ARTIST : Dennis Lloyd
# 4535 ARTIST : 17
# 4568 ARTIST : H.E.R.
# 4587 ARTIST : Keith Urban
# 4631 ARTIST : BlocBoy JB
# 4637 ARTIST : Demi Lovato
# 4638 ARTIST : Foster The People
# 4665 ARTIST : TK Kravitz
# 4673 ARTIST : A$AP Rocky
# 4748 ARTIST : Chance The Rapper
# 4874 ARTIST : David Lee Murphy
# 4882 ARTIST : Bad Wolves
# 5074 ARTIST : Sam Hunt
# 5076 ARTIST : Famous Dex
# 5077 ARTIST : Reik
# 5152 ARTIST : BTS
# 5161 ARTIST : Rae Sremmurd
# 5161 ARTIST : Juicy J
# 5228 ARTIST : DU DDU
# 5233 ARTIST : Kendrick Lamar
# 5261 ARTIST : Pitbull
# 5261 ARTIST : El Chombo
# 5263 ARTIST : KIDS SEE GHOSTS
# 5363 ARTIST : Sugarland
# 5452 ARTIST : Gorillaz
# 5456 ARTIST : Playboi Carti
# 5528 ARTIST : Pusha T
# 5531 ARTIST : Jay Rock
# 5531 ARTIST : James Blake
# 5542 ARTIST : Jennifer Lopez
# 5543 ARTIST : Darius Rucker
# 5628 ARTIST : Kevin Gates
# 5633 ARTIST : Kris Wu
# 5643 ARTIST : Pharrell Williams
# 5653 ARTIST : Meghan Trainor
# 5656 ARTIST : Bhad Bhabie
# 5752 ARTIST : Tank
# 5758 ARTIST : Justin Timberlake
# 5851 ARTIST : Mason Ramsey
# 6000 ARTIST : Portugal. The Man
# 6093 ARTIST : MAX
# 6121 ARTIST : Zayn
# 6142 ARTIST : High Valley
# 6147 ARTIST : Derez De'Shon
# 6239 ARTIST : Devin Dawson
# 6242 ARTIST : Alice Merton
# 6294 ARTIST : N*E*R*D
# 6294 ARTIST : Rihanna
# 6337 ARTIST : Luis Fonsi
# 6423 ARTIST : Lil Xan
# 6438 ARTIST : Blac Youngsta
# 6441 ARTIST : YBN Nahmir
# 6493 ARTIST : Lin
# 6494 ARTIST : Miguel
# 6539 ARTIST : Dej Loaf
# 6590 ARTIST : A$AP Ferg
# 6635 ARTIST : Saudi
# 6692 ARTIST : Macklemore
# 6731 ARTIST : Fetty Wap
# 6733 ARTIST : SOB
# 6733 ARTIST : RBE
# 6738 ARTIST : Nego do Borel
# 6815 ARTIST : Walker Hayes
# 6837 ARTIST : Becky G
# 6839 ARTIST : Janelle Monae
# 6840 ARTIST : Plies
# 6890 ARTIST : Hailee Steinfeld
# 6890 ARTIST : Alesso
# 6931 ARTIST : Liam Payne
# 6931 ARTIST : Rita Ora
# 6937 ARTIST : WALK THE MOON
# 6984 ARTIST : 800
# 7036 ARTIST : Natti Natasha
# 7038 ARTIST : Zac Efron
# 7038 ARTIST : Zendaya
# 7135 ARTIST : Easton Corbin
# 7233 ARTIST : Sofi Tukker
# 7279 ARTIST : Willy William
# 7293 ARTIST : LANCO
# 7327 ARTIST : Loren Allred
# 7422 ARTIST : Rvssian
# 7425 ARTIST : Enrique Iglesias
# 7516 ARTIST : Niall Horan
# 7520 ARTIST : X Ambassadors
# 7682 ARTIST : Tay
# 7683 ARTIST : Huncho Jack
# 7780 ARTIST : Big Sean
# 7904 ARTIST : Garth Brooks
# 7944 ARTIST : Kesha
# 7953 ARTIST : blackbear
# 7999 ARTIST : Jake Paul
# 8007 ARTIST : Shakira
# 8090 ARTIST : Carly Pearce
# 8104 ARTIST : Tim McGraw
# 8104 ARTIST : Faith Hill
# 8154 ARTIST : Coldplay
# 8155 ARTIST : GoldLink
# 8475 ARTIST : Wisin
# 8493 ARTIST : BloodPop
# 8544 ARTIST : James Arthur
# 8547 ARTIST : Cheat Codes
# 8596 ARTIST : Billy Currington
# 8781 ARTIST : Brothers Osborne
# 8880 ARTIST : Louis Tomlinson
# 8891 ARTIST : The Revivalists
# 8983 ARTIST : Lorde
# 9188 ARTIST : DeJ Loaf
# 9286 ARTIST : Fifth Harmony
# 9330 ARTIST : YFN Lucci
# 9360 ARTIST : David Guetta
# 9385 ARTIST : Major Lazer
# 9470 ARTIST : Tee Grizzley
# 9528 ARTIST : Julia Michaels
# 9569 ARTIST : China Anne McClain
# 9569 ARTIST : Thomas Doherty
# 9569 ARTIST : Dylan Playfair
# 9579 ARTIST : Sofia Carson
# 9579 ARTIST : Cameron Boyce
# 9579 ARTIST : Booboo Stewart
# 9579 ARTIST : Mitchell Hope
# 9632 ARTIST : Ayo
# 9632 ARTIST : Teo
# 9664 ARTIST : Jason Derulo
# 9677 ARTIST : Linkin Park
# 9767 ARTIST : Rascal Flatts
# 9774 ARTIST : JAY
# 9825 ARTIST : KYLE
# 9865 ARTIST : Erika Costell
# 10026 ARTIST : Shirt
# 10051 ARTIST : Harry Styles
# 10073 ARTIST : Russ
# 10265 ARTIST : Zac Brown Band
# 10273 ARTIST : Trey Songz
# 10369 ARTIST : Josh Turner
# 10471 ARTIST : Rag'n'Bone Man
# Not actually a spotify artist!
# 10545 ARTIST : Bryson Tiller
# 10555 ARTIST : Made
# 10562 ARTIST : Rag'n'Bone Man
# Not actually a spotify artist!
# 10635 ARTIST : Chris Blue
# 10657 ARTIST : Rag'n'Bone Man
# Not actually a spotify artist!
# 10735 ARTIST : Brantley Gilbert
# 10741 ARTIST : Rag'n'Bone Man
# Not actually a spotify artist!
# 10761 ARTIST : Flo Rida
# 10761 ARTIST : 99 Percent
# 10838 ARTIST : Rag'n'Bone Man
# Not actually a spotify artist!
# 10862 ARTIST : Marian Hill
# 10946 ARTIST : Rag'n'Bone Man
# Not actually a spotify artist!
# 10958 ARTIST : Starley
# 10960 ARTIST : Dwayne Johnson
# 11024 ARTIST : Lana Del Rey
# 11048 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 11049 ARTIST : Paramore
# 11124 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 11218 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 11228 ARTIST : Train
# 11235 ARTIST : Lauren Alaina
# 11304 ARTIST : Adele
# 11320 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 11332 ARTIST : Miranda Lambert
# 11356 ARTIST : Rag'n'Bone Man
# Not actually a spotify artist!
# 11414 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 11519 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 11529 ARTIST : Noah Cyrus
# 11552 ARTIST : Rick Ross
# 11601 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 11604 ARTIST : Amine
# 11617 ARTIST : Little Big Town
# 11627 ARTIST : Frank Ocean
# 11643 ARTIST : Brad Paisley
# 11699 ARTIST : Jon Bellion
# 11714 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 11806 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 11825 ARTIST : DJ Suede The Remix God
# 11840 ARTIST : John Legend
# 11847 ARTIST : PARTYNEXTDOOR
# 11933 ARTIST : Hey Violet
# 11943 ARTIST : Calum Scott
# 11997 ARTIST : Zay Hilfigerrr
# 11997 ARTIST : Zayion McCall
# 12003 ARTIST : Nick Jonas
# 12020 ARTIST : Sia
# 12029 ARTIST : Kaleo
# 12101 ARTIST : Fitz And The Tantrums
# 12138 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 12141 ARTIST : DJ Luke Nasty
# 12215 ARTIST : Missy Elliott
# 12219 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 12227 ARTIST : Granger Smith
# 12234 ARTIST : Andy Grammer
# 12285 ARTIST : Rob $tone
# 12306 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 12338 ARTIST : Flume
# 12339 ARTIST : Ugly God
# 12340 ARTIST : Wale
# 12405 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 12473 ARTIST : Young M.A
# 12500 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 12570 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 12579 ARTIST : DJ ESCO
# 12612 ARTIST : Pentatonix
# 12625 ARTIST : Opetaia Foa'i
# 12671 ARTIST : George Michael
# 12673 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 12689 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 12719 ARTIST : Mike WiLL Made
# 12721 ARTIST : Olivia O'Brien
# 12775 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 12792 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 12878 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 12886 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 12966 ARTIST : Desiigner
# 12967 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 12975 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 12980 ARTIST : gnash
# 13052 ARTIST : Auli'i Cravalho
# Not actually a spotify artist!
# 13058 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 13095 ARTIST : Frenship
# 13095 ARTIST : Emily Warren
# 13135 ARTIST : Kiiara
# 13142 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 13178 ARTIST : Britney Spears
# 13229 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 13242 ARTIST : Leonard Cohen
# 13260 ARTIST : A Tribe Called Quest
# 13276 ARTIST : Little Mix
# 13279 ARTIST : DJ Drama
# 13314 ARTIST : Daya
# 13325 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 13344 ARTIST : Usher
# 13365 ARTIST : LOCASH
# 13366 ARTIST : The Game
# 13368 ARTIST : Dae Dae
# 13418 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 13465 ARTIST : Tove Lo
# 13513 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 13601 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 13639 ARTIST : Tucker Beathard
# 13641 ARTIST : William Michael Morgan
# 13688 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 13700 ARTIST : Grace
# 13732 ARTIST : OneRepublic
# 13733 ARTIST : Artists Of Then
# 13733 ARTIST : Now
# 13733 ARTIST : Forever
# 13735 ARTIST : Solange
# 13778 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 13821 ARTIST : CL
# 13867 ARTIST : Mike Posner
# 13870 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 13961 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 14049 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 14058 ARTIST : Kent Jones
# 14133 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 14226 ARTIST : DNCE
# 14250 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 14348 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 14432 ARTIST : MadeinTYO
# 14436 ARTIST : Jacob Sartorius
# 14444 ARTIST : Young Thug And Travis Scott
# Not actually a spotify artist!
# 14450 ARTIST : Galantis
# 14497 ARTIST : James Bay
# 14515 ARTIST : Fat Joe
# 14515 ARTIST : Remy Ma
# 14515 ARTIST : Jay Z
# 14620 ARTIST : Ben Rector
# 14761 ARTIST : Ruth B
# 14767 ARTIST : MNEK
# 14801 ARTIST : David Nail
# 14807 ARTIST : The Lumineers
# 14811 ARTIST : Dreezy
# 14896 ARTIST : Blink
# 14898 ARTIST : Carlos Vives
# 14940 ARTIST : O.T. Genasis
# 14948 ARTIST : Jeremih
# 14976 ARTIST : Disturbed
# 15084 ARTIST : Red Hot Chili Peppers
# 15262 ARTIST : Belly
# 15265 ARTIST : Alan Walker
# 15356 ARTIST : Young Greatness
# 15403 ARTIST : Ghost Town DJ's
# 15544 ARTIST : Alisan Porter
# 15639 ARTIST : Kid Ink
# 15833 ARTIST : Prince And The Revolution
# 15837 ARTIST : Prince
# 16010 ARTIST : Chase Bryant
# 16021 ARTIST : Jonas Blue
# 16106 ARTIST : Robin Schulz
# 16289 ARTIST : Rachel Platten
# 16314 ARTIST : Gwen Stefani
# 16363 ARTIST : Elle King
# 16503 ARTIST : Randy Houser
# 16694 ARTIST : One Direction
# 16705 ARTIST : Empire Of The Sun
# 16788 ARTIST : Tori Kelly
# 16894 ARTIST : Fall Out Boy
# 16896 ARTIST : DLOW
# 16899 ARTIST : Dawin
# 16945 ARTIST : Silento
# 16980 ARTIST : Nelly
# 17165 ARTIST : Jana Kramer
# 17188 ARTIST : Curren$Y
# 17238 ARTIST : R. City
# 17282 ARTIST : Rudimental
# 17327 ARTIST : David Bowie
# 17454 ARTIST : Ryan Lewis
# 17519 ARTIST : iLoveMemphis
# 17526 ARTIST : Cam
# 17657 ARTIST : Lindsey Stirling
# 17699 ARTIST : Jordan Smith
# 17760 ARTIST : Adam Levine
# 17855 ARTIST : Parmalee
# 17916 ARTIST : Disciples
# 17956 ARTIST : PSY
# 18223 ARTIST : K Camp
# 18235 ARTIST : Jess Glynne
# 18475 ARTIST : Rich Homie Quan
# 18615 ARTIST : Maddie
# 18615 ARTIST : Tae
# 18619 ARTIST : The 1975
# 18710 ARTIST : Andrew McMahon In The Wilderness
# 18711 ARTIST : Adam Lambert
# 18714 ARTIST : A Great Big World
# 18850 ARTIST : Jidenna
# 18893 ARTIST : Naughty Boy
# 18946 ARTIST : Omarion
# 19073 ARTIST : Dove Cameron
# 19077 ARTIST : Pia Mia
# 19088 ARTIST : Disclosure
# 19238 ARTIST : T
# 19241 ARTIST : N.W.A
# 19407 ARTIST : AlunaGeorge
# 19540 ARTIST : Canaan Smith
# 19556 ARTIST : Sage The Gemini
# 19626 ARTIST : Bea Miller
# 19640 ARTIST : Echosmith
# 19646 ARTIST : Prince Royce
# 19776 ARTIST : Natalie La Rose
# 19825 ARTIST : Carly Rae Jepsen
# 19831 ARTIST : Tech N9Ne
# 19899 ARTIST : Steven Tyler
# 19916 ARTIST : A Thousand Horses
# 19920 ARTIST : NEEDTOBREATHE
# 19963 ARTIST : George Ezra
# 20007 ARTIST : Jessie J
# 20091 ARTIST : Grace Potter
# 20094 ARTIST : Shaggy
# 20183 ARTIST : Hilary Duff
# 20184 ARTIST : Mumford
# 20184 ARTIST : Sons
# 20188 ARTIST : Chedda Da Connect
# 20189 ARTIST : Bandit Gang Marco
# 20232 ARTIST : Ne
# 20328 ARTIST : How I Became The Bomb
# 20365 ARTIST : Jamie Foxx
# 20367 ARTIST : Dillon Francis
# 20485 ARTIST : Sawyer Fredericks
# 20496 ARTIST : Hozier
# 20538 ARTIST : Meghan Linsey
# 20539 ARTIST : Eric Paslay
# 20590 ARTIST : Tyler Farr
# 20592 ARTIST : Sheppard
# 20624 ARTIST : Nate Ruess
# 20630 ARTIST : Nick Fradiani
# 20861 ARTIST : Vance Joy
# 20978 ARTIST : LunchMoney Lewis
# 21083 ARTIST : Ludacris
# 21084 ARTIST : Who Is Fancy
# 21251 ARTIST : Breaking Benjamin
# 21261 ARTIST : Action Bronson
# 21352 ARTIST : Empire Cast
# 21363 ARTIST : James Newton Howard
# 21403 ARTIST : Ella Henderson
# 21544 ARTIST : Cashmere Cat
# 21550 ARTIST : B.o.B
# 21594 ARTIST : Common
# 21611 ARTIST : Kid Rock
# 21689 ARTIST : I LOVE MAKONNEN
# 21728 ARTIST : Florence
# 21728 ARTIST : The Machine
# 21832 ARTIST : Annie Lennox
# 21866 ARTIST : Missy "Misdemeanor" Elliott
# 21876 ARTIST : Mr. Probz
# 21921 ARTIST : Fergie
# 21924 ARTIST : RaeLynn
# 21926 ARTIST : A
# 21967 ARTIST : MAGIC!
# 21994 ARTIST : Hoodie Allen
# 22146 ARTIST : Bobby Shmurda
# 22203 ARTIST : August Alsina
# 22246 ARTIST : Milky Chance
# 22286 ARTIST : Sophia Grace
# 22288 ARTIST : I Prevail
# 22346 ARTIST : Rich Gang
# 22358 ARTIST : Colbie Caillat
# 22377 ARTIST : Nico
# 22377 ARTIST : Vinz
# 22475 ARTIST : Charli XCX
# 22496 ARTIST : Matt McAndrew
# 22515 ARTIST : Craig Wayne Boyd
# 22533 ARTIST : Chris Jamison
# 22536 ARTIST : T.I.
# 22552 ARTIST : Damien
# 22661 ARTIST : The White Buffalo
# 22661 ARTIST : The Forest Rangers
# 22744 ARTIST : Big
# 22744 ARTIST : Rich
# 22912 ARTIST : Band Aid 30
# 23032 ARTIST : The Script
# 23035 ARTIST : Snootie Wild
# 23126 ARTIST : Mary Lambert
# 23201 ARTIST : OK Go
# 23309 ARTIST : Kiesza
# 23322 ARTIST : OG Maco
# 23365 ARTIST : Tinashe
# 23406 ARTIST : Jimmy Fallon
# 23407 ARTIST : Glen Campbell
# 23506 ARTIST : TeeFLii
# 23509 ARTIST : The Swon Brothers
# 23693 ARTIST : Lil Jon
# 23695 ARTIST : alt
# 23880 ARTIST : Jeezy
# 23961 ARTIST : Joe Nichols
# 23968 ARTIST : Chris Lake
# 23968 ARTIST : Tujamo
# 24115 ARTIST : KONGOS
# 24123 ARTIST : Ingrid Michaelson
# 24151 ARTIST : KCamp
# 24210 ARTIST : MKTO
# 24324 ARTIST : Rixton
# 24347 ARTIST : Jack
# 24543 ARTIST : "Weird Al" Yankovic
# 24599 ARTIST : American Authors
# 24646 ARTIST : Ca$h Out
# 24688 ARTIST : Idina Menzel
# 24736 ARTIST : George Strait
# 24737 ARTIST : The Band Perry
# 24828 ARTIST : Busta Rhymes
# 24830 ARTIST : Craig Campbell
# 24833 ARTIST : Afrojack
# 24909 ARTIST : Robin Thicke
# 24914 ARTIST : Jamie N Commons
# 24914 ARTIST :
# Not actually a spotify artist!
# 24914 ARTIST : Ambassadors
# 25012 ARTIST : Christina Perri
# 25099 ARTIST : Neon Trees
# 25105 ARTIST : Sara Bareilles
# 25109 ARTIST :
# Not actually a spotify artist!
# 25202 ARTIST : Phillip Phillips
# 25271 ARTIST : Austin Mahone
# 25341 ARTIST : Passenger
# 25451 ARTIST : Jerrod Niemann
# 25463 ARTIST : The Black Keys
# 25477 ARTIST : Craig Morgan
# 25509 ARTIST : Aloe Blacc
# 25549 ARTIST : Hunter Hayes
# 25607 ARTIST : Christina Aguilera
# 25658 ARTIST : Kristen Bell
# 25660 ARTIST : Katy Tiz
# 25736 ARTIST : Agatha Lee Monn
# 25736 ARTIST : Katie Lopez
# 25818 ARTIST : Arctic Monkeys
# 25838 ARTIST : Frankie Ballard
# 25840 ARTIST : SoMo
# 25841 ARTIST : Sara Evans
# 25929 ARTIST : Cash Cash
# 26014 ARTIST : Santino Fontana
# 26021 ARTIST : Thompson Square
# 26190 ARTIST : John Newman
# 26200 ARTIST : K. Michelle
# 26212 ARTIST : Soko
# 26334 ARTIST : AWOLNATION
# 26371 ARTIST : U2
# 26383 ARTIST : Rico Love
# 26385 ARTIST : Daughtry
# 26454 ARTIST : The Fray
# 26464 ARTIST : Danielle Bradbery
# 26519 ARTIST : Capital Cities
# 26520 ARTIST : The Neighbourhood
# 26620 ARTIST : Sevyn Streeter
# 26645 ARTIST : Buck 22
# 26998 ARTIST : Cassadee Pope
# 27116 ARTIST : Lucy Hale
# 27195 ARTIST : Ylvis
# 27215 ARTIST : Lupe Fiasco
# 27309 ARTIST : Maejor Ali
# 27455 ARTIST : Rebecca Black
# 27455 ARTIST : Dave Days
# 27461 ARTIST : Tessanne Chin
# 27472 ARTIST : Lea Michele
# 27485 ARTIST : R. Kelly
# 27584 ARTIST : Tamar Braxton
# 27716 ARTIST : Enya
# 27767 ARTIST : Travie McCoy
# 27792 ARTIST : Bon Jovi
# 27995 ARTIST : Daft Punk
# 28040 ARTIST : Tegan And Sara
# 28084 ARTIST : Anna Kendrick
# 28111 ARTIST : Gavin DeGraw
# 28161 ARTIST : Alison Gold
# 28296 ARTIST : Pearl Jam
# 28304 ARTIST : Glee Cast
# 28409 ARTIST : Maejor Ali
# 28471 ARTIST : Tang Forever
# 28481 ARTIST : Maejor Ali
# 28507 ARTIST : Bonnie McKee
# 28523 ARTIST : Maejor Ali
# 28595 ARTIST : Charlie Worsham
# 28597 ARTIST : Armin van Buuren
# 28671 ARTIST : Sheryl Crow
# 28685 ARTIST : J. Dash
# 28687 ARTIST : Labrinth
# 28691 ARTIST : MIKA
# 28695 ARTIST : Arcade Fire
# 28696 ARTIST : Marc Anthony
# 28774 ARTIST : Nathan Sykes
# 28868 ARTIST : Avenged Sevenfold
# 28876 ARTIST : Karmin
# 28935 ARTIST : Rocko
# 28975 ARTIST : Sean Kingston
# 29023 ARTIST : Icona Pop
# 29062 ARTIST : The Wanted
# 29068 ARTIST : Fantasia
# 29156 ARTIST : Ross Lynch
# 29156 ARTIST : Grace Phipps And Jason Evigan
# Not actually a spotify artist!
# 29239 ARTIST : Grace Phipps And Jason Evigan
# Not actually a spotify artist!
# 29322 ARTIST : Grace Phipps And Jason Evigan
# Not actually a spotify artist!
# 29578 ARTIST : Emeli Sande
# 29611 ARTIST : Krewella
# 29674 ARTIST : Baauer
# 29677 ARTIST : Ace Hood
# 29870 ARTIST : Jack Johnson
# 29877 ARTIST : Fabolous
# 29962 ARTIST : Hadouken!
# 29969 ARTIST : Gloriana
# 30037 ARTIST : Olly Murs
# 30053 ARTIST : Zach Sobiech
# 30060 ARTIST : Kelly Rowland
# 30146 ARTIST : Q
# 30202 ARTIST : fun.
# 30239 ARTIST : Candice Glover
# 30282 ARTIST : will.i.am
# 30319 ARTIST : Guy Sebastian
# 30338 ARTIST : Young Jeezy
# 30381 ARTIST : Swedish House Mafia
# 30406 ARTIST : Ray J
# 30429 ARTIST : Arianna
# 30510 ARTIST : Trinidad James
# 30567 ARTIST : Of Monsters And Men
# 30701 ARTIST : WE the Kings
# 30751 ARTIST : Muse
# 30796 ARTIST : Ke$ha
# 30840 ARTIST : Alicia Keys
# 30981 ARTIST : Jonn Hart
# 31079 ARTIST : Britt Nicole
# 31085 ARTIST : Chief Keef
# 31275 ARTIST : Michael Buble
# 31372 ARTIST : Alabama Shakes
# 31413 ARTIST : Gotye
# 31429 ARTIST : Gary Allan
# 31473 ARTIST : Joe Budden
# 31475 ARTIST : Casey James
# 31571 ARTIST : Chris Cagle
# 31617 ARTIST : Jay
# 31633 ARTIST : The Lonely Island
# 31659 ARTIST : Passion Pit
# 31717 ARTIST : Alex Clare
# 31762 ARTIST : Game
# 31863 ARTIST : Lifehouse
# 31953 ARTIST : Anne Hathaway
# 31956 ARTIST : Bridgit Mendler
# 32050 ARTIST : Greg Bates
# 32051 ARTIST : Samantha Barks
# 32125 ARTIST : Cher Lloyd
# 32142 ARTIST : Kid Cudi
# 32337 ARTIST : 50 Cent
# 32384 ARTIST : Owl City
# 32420 ARTIST : Terry McDermott
# 32524 ARTIST : Melanie Martinez
# 32618 ARTIST : The Nocturnals
# 32705 ARTIST : Brandy
# 33004 ARTIST : Sam Palladio
# 33004 ARTIST : Clare Bowen
# 33104 ARTIST : matchbox twenty
# 33381 ARTIST : Love And Theft
# 33395 ARTIST : Keyshia Cole
# 33596 ARTIST : Green Day
# 33672 ARTIST : Grouplove
# 33677 ARTIST : No Doubt
# 33687 ARTIST : NERO
# 33831 ARTIST : Havana Brown
# 33871 ARTIST : Gym Class Heroes
# 33880 ARTIST : Slaughterhouse
# 34243 ARTIST : Toby Keith
# 34250 ARTIST : The Killers
# 34344 ARTIST : M83.
# 34352 ARTIST : Dave Matthews Band
# 34492 ARTIST : Kirko Bangz
# 34544 ARTIST : Travis Porter
# 34634 ARTIST : Big Time Rush
# 34726 ARTIST : Michel Telo
# 34776 ARTIST : LMFAO
# 34890 ARTIST : Waka Flocka Flame
# 34996 ARTIST : Jay Sean
# 35143 ARTIST : Snoop Dogg
# 35257 ARTIST : Tony Lucca
# 35561 ARTIST : Jennifer Hudson
# 35642 ARTIST : Juliet Simms
# 35647 ARTIST : K'Naan
# Not actually a spotify artist!
# 35649 ARTIST : Montgomery Gentry
# 35743 ARTIST : Shinedown
# 35746 ARTIST : K'Naan
# Not actually a spotify artist!
# 35818 ARTIST : Sean Paul
# 35823 ARTIST : Diggy
# 35826 ARTIST : Madonna
# 35836 ARTIST : Mary J. Blige
# 35838 ARTIST : Dev
# 35929 ARTIST : Bella Thorne
# 36021 ARTIST : Breathe Carolina
# 36064 ARTIST : The Scene
# 36116 ARTIST : Young The Giant
# 36208 ARTIST : Estelle
# 36235 ARTIST : Whitney Houston
# 36343 ARTIST : Hot Chelle Rae
# 36374 ARTIST : Martina McBride
# 36397 ARTIST : deadmau5
# 36753 ARTIST : Edens Edge
# 36827 ARTIST : Van Halen
# 36838 ARTIST : Snow Patrol
# 36855 ARTIST : Nickelback
# 36935 ARTIST : 3OH!3
# 37038 ARTIST : V.I.C.
# 37044 ARTIST : Roscoe Dash
# 37460 ARTIST : Alexandra Stan
# 37515 ARTIST : Mana
# 37653 ARTIST : Bad Meets Evil
# 37659 ARTIST : Matt Nathanson
# 37690 ARTIST : Ronnie Dunn
# 37750 ARTIST : Rodney Atkins
# 37776 ARTIST : New Boyz
# 37782 ARTIST : Mindless Behavior
# 37841 ARTIST : Bow Wow
# 37883 ARTIST : Kaskade
# 37885 ARTIST : Lloyd
# 38056 ARTIST : Trace Adkins
# 38074 ARTIST : Evanescence
# 38130 ARTIST : Taio Cruz
# 38165 ARTIST : Iyaz
# 38166 ARTIST : Steve Holy
# 38257 ARTIST : Kreayshawn
# 38258 ARTIST : Foo Fighters
# 38322 ARTIST : Birdman
# 38397 ARTIST : The Black Eyed Peas
# 38421 ARTIST : Hugh Laurie
# 38434 ARTIST : Tony Bennett
# 38434 ARTIST : Amy Winehouse
# 38527 ARTIST : JoJo
# 38537 ARTIST : Pistol Annies
# 38724 ARTIST : Tinie Tempah
# 38780 ARTIST : Martin Solveig
# 38780 ARTIST : Dragonette
# 38803 ARTIST : Nicole Scherzinger
# 38987 ARTIST : Mat Kearney
# 39091 ARTIST : Kirk Franklin
# 39177 ARTIST : YC
# 39183 ARTIST : Marsha Ambrosius
# 39273 ARTIST : Seether
# 39366 ARTIST : Javier Colon
# 39367 ARTIST : Don Omar
# 39388 ARTIST : Dia Frampton
# 39539 ARTIST : Victorious Cast
# 39548 ARTIST : Jill Scott
# 39611 ARTIST : Shania Twain
# 39624 ARTIST : Dr. Dre
# 39635 ARTIST : Joe Jonas
# 39826 ARTIST : Lucenzo
# 39828 ARTIST : Rej3ctz
# 39830 ARTIST : My Chemical Romance
# 39899 ARTIST : Reeve Carney
# 40013 ARTIST : Ashton Shepherd
# 40094 ARTIST : Jordin Sparks
# 40151 ARTIST : Diddy
# 40206 ARTIST : Thirty Seconds To Mars
# 40273 ARTIST : Adam Hicks
# 40273 ARTIST : Naomi Scott
# 40273 ARTIST : Hayley Kiyoko
# 40285 ARTIST : Akon
# 40291 ARTIST : Duck Sauce
# 40340 ARTIST : Keri Hilson
# 40441 ARTIST : Edward Maya
# 40441 ARTIST : Vika Jigulina
# 40449 ARTIST : Far*East Movement
# 40575 ARTIST : Josh Kelley
# 40581 ARTIST : Mary Mary
# 40651 ARTIST : Sara Ramirez
# 40768 ARTIST : Mann
# 40770 ARTIST : Sunny Sweeney
# 40772 ARTIST : Cage The Elephant
# 40868 ARTIST : Miranda Cosgrove
# 41034 ARTIST : Gorilla Zoe
# 41040 ARTIST : Chris Medina
# 41041 ARTIST : Sick Puppies
# 41042 ARTIST : WILLOW
# 41043 ARTIST : Aaron Lewis
# 41044 ARTIST : The JaneDear Girls
# 41146 ARTIST : Kanye West Jay Z
# Not actually a spotify artist!
# 41238 ARTIST : Kanye West Jay Z
# Not actually a spotify artist!
# 41243 ARTIST : Troop 41
# 41332 ARTIST : Kanye West Jay Z
# Not actually a spotify artist!
# 41333 ARTIST : Twista
# 41335 ARTIST : New Hollow
# 41373 ARTIST : Plain White T's
# 41414 ARTIST : 3 Doors Down
# 41419 ARTIST : Kanye West Jay Z
# Not actually a spotify artist!
# 41506 ARTIST : Kanye West Jay Z
# Not actually a spotify artist!
# 41513 ARTIST : Yolanda Be Cool
# 41513 ARTIST : Dcup
# 41514 ARTIST : Rise Against
# 41570 ARTIST : Kanye West Jay Z
# Not actually a spotify artist!
# 41613 ARTIST : James Blunt
# 41617 ARTIST : Garrett Hedlund
# 41617 ARTIST : Leighton Meester
# 41619 ARTIST : Yellowcard
# 41640 ARTIST : Kanye West Jay Z
# Not actually a spotify artist!
# 41701 ARTIST : Gwyneth Paltrow
# 41712 ARTIST : Reba
# 41805 ARTIST : My Darkest Days
# 41841 ARTIST : The Ready Set
# 41896 ARTIST : Jesse McCartney
# 41901 ARTIST : Chiddy Bang
# 42174 ARTIST : Natasha Bedingfield
# 42550 ARTIST : Jazmine Sullivan
# 42638 ARTIST : Monica
# 42645 ARTIST : ROCKMAFIA
# 42647 ARTIST : Kings Of Leon
# 42805 ARTIST : Hannah Montana
# 42823 ARTIST : Josh Thompson
# 42983 ARTIST : Cali Swag District
# 43015 ARTIST : A Rocket To The Moon
# 43117 ARTIST : Soulja Boy Tell'em
# 43193 ARTIST : Soulja Boy Tell'em
# 43254 ARTIST : Uncle Kracker
# 43276 ARTIST : Soulja Boy Tell'em
# 43293 ARTIST : Gyptian
# 43354 ARTIST : Soulja Boy Tell'em
# 43381 ARTIST : Chris Willis
# 43435 ARTIST : La Roux
# 43443 ARTIST : Shontelle
# 43445 ARTIST : Soulja Boy Tell'em
# 43478 ARTIST : Antoine Dodson
# 43478 ARTIST : The Gregory Brothers
# 43531 ARTIST : Soulja Boy Tell'em
# 43569 ARTIST : Bobby Brackins
# 43574 ARTIST : Rob Thomas
# 43615 ARTIST : Soulja Boy Tell'em
# 43625 ARTIST : Thinkable
# Not actually a spotify artist!
# 43663 ARTIST : Soundgarden
# 43700 ARTIST : Soulja Boy Tell'em
# 43709 ARTIST : Thinkable
# Not actually a spotify artist!
# 43790 ARTIST : Soulja Boy Tell'em
# 43794 ARTIST : Thinkable
# Not actually a spotify artist!
# 43841 ARTIST : Jaron And The Long Road To Love
# 43877 ARTIST : Thinkable
# Not actually a spotify artist!
# 43882 ARTIST : Soulja Boy Tell'em
# 43921 ARTIST : Asher Roth
# 43936 ARTIST : Clay Walker
# 43963 ARTIST : Thinkable
# Not actually a spotify artist!
# 43976 ARTIST : Soulja Boy Tell'em
# 44051 ARTIST : Thinkable
# Not actually a spotify artist!
# 44078 ARTIST : Soulja Boy Tell'em
# 44108 ARTIST : Timbaland
# 44120 ARTIST : K'Naan
# Not actually a spotify artist!
# 44144 ARTIST : Thinkable
# Not actually a spotify artist!
# 44180 ARTIST : Soulja Boy Tell'em
# 44202 ARTIST : K'Naan
# Not actually a spotify artist!
# 44204 ARTIST : V V Brown
# 44240 ARTIST : Thinkable
# Not actually a spotify artist!
# 44283 ARTIST : Soulja Boy Tell'em
# 44307 ARTIST : K'Naan
# Not actually a spotify artist!
# 44338 ARTIST : Thinkable
# Not actually a spotify artist!
# 44391 ARTIST : Soulja Boy Tell'em
# 44393 ARTIST : K'Naan
# Not actually a spotify artist!
# 44427 ARTIST : Thinkable
# Not actually a spotify artist!
# 44482 ARTIST : K'Naan
# Not actually a spotify artist!
# 44490 ARTIST : Soulja Boy Tell'em
# 44494 ARTIST : Jaheim
# 44520 ARTIST : Thinkable
# Not actually a spotify artist!
# 44581 ARTIST : K'Naan
# Not actually a spotify artist!
# 44584 ARTIST : Lloyd Banks
# 44588 ARTIST : Steel Magnolia
# 44620 ARTIST : Thinkable
# Not actually a spotify artist!
# 44659 ARTIST : Lee DeWyze
# 44682 ARTIST : Young Money
# 44712 ARTIST : Thinkable
# Not actually a spotify artist!
# 44735 ARTIST : Crystal Bowersox
# 44757 ARTIST : Will Young
# 44800 ARTIST : Thinkable
# Not actually a spotify artist!
# 44859 ARTIST : Charice
# 44864 ARTIST : Erykah Badu
# 44898 ARTIST : Thinkable
# Not actually a spotify artist!
# 44912 ARTIST : Kris Allen
# 44955 ARTIST : Spose
# 44959 ARTIST : Maxwell
# 45002 ARTIST : Thinkable
# Not actually a spotify artist!
# 45053 ARTIST : Theory Of A Deadman
# 45095 ARTIST : Thinkable
# Not actually a spotify artist!
# 45146 ARTIST : The
# 45148 ARTIST : Alpha Rev
# 45193 ARTIST : Orianthi
# 45203 ARTIST : Thinkable
# Not actually a spotify artist!
# 45319 ARTIST : Thinkable
# Not actually a spotify artist!
# 45419 ARTIST : Thinkable
# Not actually a spotify artist!
# 45521 ARTIST : Matisyahu
# 45525 ARTIST : Melanie Fiona
# 45614 ARTIST : Sade
# 45705 ARTIST : Disney's Friends For Change
# Not actually a spotify artist!
# 45719 ARTIST : Phoenix
# 45766 ARTIST : Boys Like Girls
# 45807 ARTIST : Sam Adams
# 45810 ARTIST : Mario
# 45889 ARTIST : Danny Gokey
# 45987 ARTIST : General Larry Platt
# 45998 ARTIST : Creed
# 45999 ARTIST : Kellie Pickler
# 46060 ARTIST : k.d. lang
# 46076 ARTIST : Christopher Wilde
# 46238 ARTIST : Cascada
# 46265 ARTIST : Andrea Bocelli
# 46275 ARTIST : Matt Morris
# 46277 ARTIST : The Administration
# 46285 ARTIST : Shiny Toy Guns
# 46378 ARTIST : Eddie Vedder
# 46385 ARTIST : Jason Michael Carroll
# 46479 ARTIST : Three Days Grace
# 46580 ARTIST : Cobra Starship
# 46766 ARTIST : Ester Dean
# 47135 ARTIST : Michael Franti
# 47135 ARTIST : Spearhead
# 47153 ARTIST : Leona Lewis
# 47171 ARTIST : LeToya
# 47233 ARTIST : Susan Boyle
# 47264 ARTIST : Francesca Battistelli
# 47451 ARTIST : Anya Marina
# 47646 ARTIST : Pleasure P
# 47649 ARTIST : Chamillionaire
# 47821 ARTIST : Wonder Girls
# 47828 ARTIST : Five For Fighting
# 47901 ARTIST : Dorrough
# 47932 ARTIST : Darryl Worley
# 47938 ARTIST : Alice In Chains
# 48121 ARTIST : The All
# 48221 ARTIST : David Cook
# 48222 ARTIST : Ginuwine
# 48303 ARTIST : Jack Ingram
# 48304 ARTIST : Disney's Friends For Change
# Not actually a spotify artist!
# 48309 ARTIST : Parachute
# 48315 ARTIST : Three 6 Mafia
# 48381 ARTIST : Disney's Friends For Change
# Not actually a spotify artist!
# 48459 ARTIST : Disney's Friends For Change
# Not actually a spotify artist!
# 48513 ARTIST : Skillet
# 48534 ARTIST : Disney's Friends For Change
# Not actually a spotify artist!
# 48578 ARTIST : Jessie James
# 48629 ARTIST : Disney's Friends For Change
# Not actually a spotify artist!
# 48703 ARTIST : Matt And Kim
# 48705 ARTIST : Carolina Liar
# 48754 ARTIST : The Ting Tings
# 48783 ARTIST : Kristinia DeBarge
# 48892 ARTIST : Michelle Branch
# 48988 ARTIST : Beastie Boys
# 49144 ARTIST : Maino
# 49268 ARTIST : Alan Jackson
# 49321 ARTIST : Soulja Boy Tell 'em
# 49351 ARTIST : The Veronicas
# 49456 ARTIST : Madcon
# 49538 ARTIST : Mitchel Musso
# 49540 ARTIST : Musiq Soulchild
# 49552 ARTIST : K'Jon
# Not actually a spotify artist!
# 49646 ARTIST : Yung L.A.
# 49647 ARTIST : K'Jon
# Not actually a spotify artist!
# 49918 ARTIST : Paula Abdul
# 49919 ARTIST : Chrisette Michele
# 49992 ARTIST : GS Boyz
# 50011 ARTIST : Mike Jones
# 50012 ARTIST : Charlie Wilson
# 50100 ARTIST : Lily Allen
# 50145 ARTIST : Kevin Rudolf
# 50179 ARTIST : The White Tie Affair
# 50184 ARTIST : Billy Ray Cyrus
# 50190 ARTIST : DAY26
# 50191 ARTIST : Kart
# 50277 ARTIST : John Rich
# 50281 ARTIST : Mims
# 50282 ARTIST : Silversun Pickups
# 50288 ARTIST : Ashley Tisdale
# 50335 ARTIST : The Pussycat Dolls
# 50378 ARTIST : MGMT
# 50464 ARTIST : Papa Roach
# 50473 ARTIST : Mac McAnally
# 50547 ARTIST : Brooks
# 50547 ARTIST : Dunn
# 50642 ARTIST : Bobby V
# 50737 ARTIST : Lee Ann Womack
# 50744 ARTIST : Thriving Ivory
# 50745 ARTIST : Framing Hanley
# 50891 ARTIST : Brooke White
# 50903 ARTIST : Jim Jones
# 50903 ARTIST : Ron Browz
# 50928 ARTIST : Ludacris Co
# 50939 ARTIST : K'Naan
# Not actually a spotify artist!
# 51005 ARTIST : Ludacris Co
# 51028 ARTIST : Spectacular! Cast
# 51088 ARTIST : Ludacris Co
# 51169 ARTIST : Ludacris Co
# 51203 ARTIST : The Offspring
# 51212 ARTIST : Bruce Springsteen
# 51252 ARTIST : Ludacris Co
# 51264 ARTIST : Saving Abel
# 51293 ARTIST : Pat Green
# 51306 ARTIST : Apocalyptica
# 51337 ARTIST : Ludacris Co
# 51433 ARTIST : Ludacris Co
# 51442 ARTIST : David Archuleta
# 51449 ARTIST : O.A.R.
# 51487 ARTIST : Metro Station
# 51494 ARTIST : Hinder
# 51499 ARTIST : The Rock Heroes
# 51523 ARTIST : Ludacris Co
# 51591 ARTIST : Avant
# 51624 ARTIST : Ludacris Co
# 51635 ARTIST : Secondhand Serenade
# 51639 ARTIST : Gavin Rossdale
# 51719 ARTIST : Ludacris Co
# 51809 ARTIST : Ludacris Co
# 51905 ARTIST : Ludacris Co
# 51945 ARTIST : Savage
# 52002 ARTIST : Ludacris Co
# 52062 ARTIST : Slim
# 52095 ARTIST : Ludacris Co
# 52114 ARTIST : M.I.A.
# 52133 ARTIST : Ludacris Co
# 52148 ARTIST : Guns N' Roses
# 52157 ARTIST : Ludacris Co
# 52161 ARTIST : Jimmy Wayne
# 52202 ARTIST : Ludacris Co
# 52243 ARTIST : Jack White
# 52249 ARTIST : Bucky Covington
# 52260 ARTIST : Ludacris Co
# 52313 ARTIST : Ludacris Co
# 52348 ARTIST : Ludacris Co
# 52405 ARTIST : Kardinal Offishall
# 52409 ARTIST : Ludacris Co
# 52418 ARTIST : Ludacris Co
# 52446 ARTIST : Buckcherry
# 52491 ARTIST : Ludacris Co
# 52530 ARTIST : High School Musical 3 Cast
# Not actually a spotify artist!
# 52531 ARTIST : Ludacris Co
# 52540 ARTIST : Metallica
# 52543 ARTIST : Vanessa Hudgens
# 52582 ARTIST : Ludacris Co
# 52612 ARTIST : High School Musical 3 Cast
# Not actually a spotify artist!
# 52638 ARTIST : Chuck Wicks
# 52673 ARTIST : Ludacris Co
# 52722 ARTIST : September
# 52724 ARTIST : Ray LaMontagne
# 52733 ARTIST : Keith Anderson
# 52770 ARTIST : Ludacris Co
# 52807 ARTIST : Yung Berg
# 52823 ARTIST : Oasis
# 52872 ARTIST : Ludacris Co
# 52922 ARTIST : LL Cool J
# 52964 ARTIST : Ludacris Co
# 52971 ARTIST : David Banner
# 53014 ARTIST : The Lost Trailers
# 53069 ARTIST : Ludacris Co
# 53112 ARTIST : Joshua Radin
# 53164 ARTIST : Ludacris Co
# 53200 ARTIST : Shwayze
# 53255 ARTIST : Ludacris Co
# 53296 ARTIST : High School Musical 3 Cast
# Not actually a spotify artist!
# 53297 ARTIST : Duffy
# 53301 ARTIST : Marvin Sapp
# 53357 ARTIST : Ludacris Co
# 53389 ARTIST : Staind
# 53443 ARTIST : Flobots
# 53528 ARTIST : Colby O'Donis
# 53564 ARTIST : Goo Goo Dolls
# 53613 ARTIST : Danity Kane
# 53640 ARTIST : Melissa Lawson
# 53647 ARTIST : New Kids On The Block
# 53655 ARTIST : Jessica Simpson
# 53745 ARTIST : Flex
# 53835 ARTIST : Josh Gracin
# 53905 ARTIST : Flyleaf
# 53928 ARTIST : Nas
# 54018 ARTIST : Julianne Hough
# 54082 ARTIST : James Otto
# 54104 ARTIST : Cast Of Camp Rock
# 54110 ARTIST : Ashanti
# 54178 ARTIST : 2 Pistols
# 54201 ARTIST : Death Cab For Cutie
# 54371 ARTIST : Phil Vassar
# 54384 ARTIST : Yael Naim
# 54475 ARTIST : Raheem DeVaughn
# 54564 ARTIST : Puddle Of Mudd
# 54641 ARTIST : Ferras
# 54692 ARTIST : Finger Eleven
# 54708 ARTIST : Kate Voegele
# 54717 ARTIST : American Girl
# 54720 ARTIST : Cherish
# 54732 ARTIST : C
# 54737 ARTIST : Jewel
# 54831 ARTIST : Lil Mama
# 54907 ARTIST : Shawty Lo
# 54914 ARTIST : Augustana
# 55014 ARTIST : G Unit
# 55015 ARTIST : Ashlee Simpson
# 55015 ARTIST : Tom Higgenson
# 55018 ARTIST : Soulja Boy Tell'em
# 55064 ARTIST : J. Holiday
# 55090 ARTIST : Soulja Boy Tell'em
# 55181 ARTIST : Soulja Boy Tell'em
# 55240 ARTIST : Radiohead
# 55273 ARTIST : Soulja Boy Tell'em
# 55286 ARTIST : R.E.M.
# 55362 ARTIST : Soulja Boy Tell'em
# 55368 ARTIST : Enur
# 55390 ARTIST : Ryan Leslie
# 55436 ARTIST : Wyclef Jean
# 55446 ARTIST : Soulja Boy Tell'em
# 55475 ARTIST : Gnarls Barkley
# 55478 ARTIST : Aly
# 55478 ARTIST : AJ
# 55535 ARTIST : Soulja Boy Tell'em
# 55577 ARTIST : The Swell Season
# 55622 ARTIST : Soulja Boy Tell'em
# 55655 ARTIST : DJ Felli Fel
# 55723 ARTIST : Soulja Boy Tell'em
# 55800 ARTIST : Santana
# 55817 ARTIST : Soulja Boy Tell'em
# 55896 ARTIST : Soulja Boy Tell'em
# 55898 ARTIST : Baby Bash
# 55915 ARTIST : Soulja Boy Tell'em
# 55919 ARTIST : Celine Dion
# 55919 ARTIST : Josh Groban
# 55943 ARTIST : Lenny Kravitz
# 55986 ARTIST : Soulja Boy Tell'em
# 56017 ARTIST : Soulja Boy Tell'em
# 56038 ARTIST : The Last Goodnight
# 56074 ARTIST : Soulja Boy Tell'em
# 56111 ARTIST : Playaz Circle
# 56119 ARTIST : Soulja Boy Tell'em
# 56131 ARTIST : DragonForce
# 56161 ARTIST : Soulja Boy Tell'em
# 56248 ARTIST : Soulja Boy Tell'em
# 56313 ARTIST : Michael Cera
# 56313 ARTIST : Ellen Page
# 56330 ARTIST : Soulja Boy Tell'em
# 56392 ARTIST : Soulja Boy Tell'em
# 56398 ARTIST : Alvin And The Chipmunks
# 56416 ARTIST : Soulja Boy Tell'em
# 56468 ARTIST : Soulja Boy Tell'em
# 56485 ARTIST : Feist
# 56502 ARTIST : Soulja Boy Tell'em
# 56545 ARTIST : Soulja Boy Tell'em
# 56586 ARTIST : Landon Pigg
# 56588 ARTIST : Chingy
# 56602 ARTIST : Soulja Boy Tell'em
# 56645 ARTIST : Soulja Boy Tell'em
# 56676 ARTIST : Juanes
# 56693 ARTIST : Soulja Boy Tell'em
# 56731 ARTIST : Soulja Boy Tell'em
# 56786 ARTIST : Soulja Boy Tell'em
# 56812 ARTIST : Soulja Boy Tell'em
# 56876 ARTIST : Soulja Boy Tell'em
# 56900 ARTIST : Soulja Boy Tell'em
# 56957 ARTIST : Yandel
# 56964 ARTIST : Soulja Boy Tell'em
# 56990 ARTIST : Soulja Boy Tell'em
# 57043 ARTIST : Hurricane Chris
# 57056 ARTIST : Soulja Boy Tell'em
# 57085 ARTIST : Soulja Boy Tell'em
# 57145 ARTIST : Soulja Boy Tell'em
# 57177 ARTIST : Soulja Boy Tell'em
# 57183 ARTIST : Elliott Yamin
# 57235 ARTIST : Soulja Boy Tell'em
# 57266 ARTIST : Soulja Boy Tell'em
# 57326 ARTIST : Soulja Boy Tell'em
# 57357 ARTIST : Soulja Boy Tell'em
# 57412 ARTIST : Serj Tankian
# 57416 ARTIST : Soulja Boy Tell'em
# 57457 ARTIST : Soulja Boy Tell'em
# 57509 ARTIST : Soulja Boy Tell'em
# 57564 ARTIST : Soulja Boy Tell'em
# 57577 ARTIST : Kat DeLuna
# 57602 ARTIST : Soulja Boy Tell'em
# 57669 ARTIST : Soulja Boy Tell'em
# 57694 ARTIST : Soulja Boy Tell'em
# 57782 ARTIST : Cupid
# 57784 ARTIST : Soulja Boy Tell'em
# 57864 ARTIST : Swizz Beatz
# 57873 ARTIST : Soulja Boy Tell'em
# 57915 ARTIST : Shop Boyz
# 57938 ARTIST : Down A.K.A. Kilo
# 57950 ARTIST : Nelly Furtado
# 57960 ARTIST : Soulja Boy Tell'em
# 58038 ARTIST : Paula DeAnda
# 58039 ARTIST : High School Musical 2 Cast
# Not actually a spotify artist!
# 58047 ARTIST : Soulja Boy Tell'em
# 58114 ARTIST : Yung Joc
# 58119 ARTIST : High School Musical 2 Cast
# Not actually a spotify artist!
# 58126 ARTIST : Eve
# 58132 ARTIST : Lil Boosie
# 58134 ARTIST : Soulja Boy Tell'em
# 58177 ARTIST : High School Musical 2 Cast
# Not actually a spotify artist!
# 58190 ARTIST : Corbin Bleu
# 58190 ARTIST : Lucas Grabeel
# 58221 ARTIST : Soulja Boy Tell'em
# 58245 ARTIST : High School Musical 2 Cast
# Not actually a spotify artist!
# 58295 ARTIST : Tracy Lawrence
# 58298 ARTIST : The White Stripes
# 58309 ARTIST : Soulja Boy Tell'em
# 58329 ARTIST : High School Musical 2 Cast
# Not actually a spotify artist!
# 58398 ARTIST : Soulja Boy Tell'em
# 58410 ARTIST : High School Musical 2 Cast
# Not actually a spotify artist!
# 58465 ARTIST : Emerson Drive
# 58491 ARTIST : High School Musical 2 Cast
# Not actually a spotify artist!
# 58492 ARTIST : Soulja Boy Tell'em
# 58512 ARTIST : Huey
# 58542 ARTIST : Bone Thugs
# 58555 ARTIST : Bobby Valentino
# 58564 ARTIST : High School Musical 2 Cast
# Not actually a spotify artist!
# 58582 ARTIST : Soulja Boy Tell'em
# 58685 ARTIST : Soulja Boy Tell'em
# 58857 ARTIST : Unk
# 58877 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 58958 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 58959 ARTIST : Crime Mob
# 58995 ARTIST : Dashboard Confessional
# 58999 ARTIST : The Smashing Pumpkins
# 59001 ARTIST : Ozzy Osbourne
# 59032 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 59078 ARTIST : Blake Lewis
# 59115 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 59198 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 59218 ARTIST : The Red Jumpsuit Apparatus
# 59229 ARTIST : India.Arie
# 59287 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 59363 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 59430 ARTIST : Katharine McPhee
# 59451 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 59539 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 59603 ARTIST : Paul Wall
# 59605 ARTIST : Lumidee
# 59607 ARTIST : Incubus
# 59610 ARTIST : Joe
# 59611 ARTIST : Pretty Ricky
# 59628 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 59652 ARTIST : Rich Boy
# 59713 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 59766 ARTIST : Blue October
# 59793 ARTIST : Young Buck
# 59803 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 59860 ARTIST : Brandi Carlile
# 59868 ARTIST : Bjork
# 59877 ARTIST : Good Charlotte
# 59896 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 59987 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 60046 ARTIST : Modest Mouse
# 60065 ARTIST : Marques Houston
# 60079 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 60105 ARTIST : Hellogoodbye
# 60138 ARTIST : Joss Stone
# 60143 ARTIST : Regina Spektor
# 60145 ARTIST : The Fratellis
# 60146 ARTIST : Jibbs
# 60171 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 60213 ARTIST : Nine Inch Nails
# 60279 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 60280 ARTIST : Dixie Chicks
# 60398 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 60414 ARTIST : Korn
# 60468 ARTIST : KT Tunstall
# 60491 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 60505 ARTIST : AnnaSophia Robb
# 60510 ARTIST : Corinne Bailey Rae
# 60593 ARTIST : Jordan Pruitt
# 60597 ARTIST : R. Kelly Or Bow Wow
# Not actually a spotify artist!
# 60604 ARTIST : Lil' Boosie
# 60691 ARTIST : Norah Jones
# 60769 ARTIST : The Naked Brothers Band
# 60778 ARTIST : Trent Tomlinson
# 60820 ARTIST : Stone Sour
# 60843 ARTIST : Lil Scrappy
# 60861 ARTIST : The Shins
# 60862 ARTIST : The Wreckers
# 60863 ARTIST : Petey Pablo
# 60869 ARTIST : Molly
# 60873 ARTIST : Cartel
# 61037 ARTIST : Ca$his
# 61043 ARTIST : AFI
# 61138 ARTIST : Lady Sovereign
# 61229 ARTIST : Webstar
# 61229 ARTIST : Young B
# 61316 ARTIST : Sarah McLachlan
# 61320 ARTIST : Heartland
# 61330 ARTIST : RBD
# 61501 ARTIST : Lonestar
# 61591 ARTIST : Mario Vazquez
# 61592 ARTIST : Brooke Hogan
# 61596 ARTIST : Ying Yang Twins
# 61600 ARTIST : Lyfe Jennings
# 61605 ARTIST : Lionel Richie
# 61607 ARTIST : Chris Cornell
# 61692 ARTIST : Shareefa
# 61898 ARTIST : Bowling For Soup
# 61900 ARTIST : Alejandro Sanz
# 61991 ARTIST : Ruben Studdard
# 61997 ARTIST : Toby Love
# 62044 ARTIST : E
# 62083 ARTIST : John Mellencamp
# 62095 ARTIST : Cassie
# 62185 ARTIST : Fort Minor
# 62226 ARTIST : Young Dro
# 62282 ARTIST : Nick Lachey
# 62544 ARTIST : The Raconteurs
# 62561 ARTIST : Cham
# 62571 ARTIST : Brown Boy
# 62572 ARTIST : Paulina Rubio
# 62615 ARTIST : Kelis
# 62619 ARTIST : Daniel Powter
# 62664 ARTIST : The Pack
# 62744 ARTIST : Paris Hilton
# 62761 ARTIST : Keane
# 62813 ARTIST : The Cheetah Girls
# 62901 ARTIST : Field Mob
# 62947 ARTIST : OutKast
# 63039 ARTIST : Anna Nalick
# 63045 ARTIST : Taking Back Sunday
# 63221 ARTIST : Pharrell
# 63228 ARTIST : Jeannie Ortega
# 63229 ARTIST : Cheyenne Kimball
# 63231 ARTIST : Taylor Hicks
# 63324 ARTIST : Audioslave
# 63400 ARTIST : Lustra
# 63405 ARTIST : Ashley Parker Angel
# 63419 ARTIST : Shawnna
# 63504 ARTIST : Angels
# 63504 ARTIST : Airwaves
# 63505 ARTIST : RKM
# 63505 ARTIST : Ken
# 63513 ARTIST : Anthony Hamilton
# 63607 ARTIST : LeAnn Rimes
# 63609 ARTIST : Tom Petty
# 63692 ARTIST : Dem Franchize Boyz
# 63697 ARTIST : Kenny Rogers
# 63783 ARTIST : Saving Jane
# 63788 ARTIST : Christina Milian
# 63793 ARTIST : Bo Bice
# 63845 ARTIST : Teddy Geiger
# 63875 ARTIST : Ice Cube
# 63963 ARTIST : Chris Daughtry
# 63967 ARTIST : Jagged Edge
# 64044 ARTIST : Ghostface Killah
# 64045 ARTIST : Mary J. Blige And U2
# Not actually a spotify artist!
# 64050 ARTIST : Olivia
# 64319 ARTIST : Heather Headley
# 64325 ARTIST : The Afters
# 64512 ARTIST : Godsmack
# 64602 ARTIST : Sting
# 64780 ARTIST : Yeah Yeah Yeahs
# 64861 ARTIST : Juvenile
# 64957 ARTIST : Juelz Santana
# 64959 ARTIST : Lil Rob
# 64961 ARTIST : D4L
# 64964 ARTIST : 10 Years
# 65056 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 65120 ARTIST : Bird York
# 65144 ARTIST : The Notorious B.I.G.
# 65147 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 65233 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 65234 ARTIST : HIM
# 65244 ARTIST : Relient K
# 65317 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 65386 ARTIST : Willie Nelson
# 65395 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 65421 ARTIST : Andrew Seeley
# 65430 ARTIST : High School Musical Cast
# 65475 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 65495 ARTIST : Michael Stipe
# 65563 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 65587 ARTIST : P.O.D.
# 65594 ARTIST : Trina
# 65609 ARTIST : System Of A Down
# 65656 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 65740 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 65830 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 65931 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 65972 ARTIST : Cast Of Rent
# 66036 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 66067 ARTIST : YoungBloodZ
# 66071 ARTIST : Frankie J
# 66079 ARTIST : INXS
# 66116 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 66207 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 66309 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 66343 ARTIST : Cristian Castro
# 66412 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 66453 ARTIST : Lil' Kim
# 66460 ARTIST : Trick
# 66514 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# 66528 ARTIST : The Click Five
# 66625 ARTIST : Purple Ribbon All
# Not actually a spotify artist!
# ...
# 85958 ARTIST : Ian Van Dahl
# 85971 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 86061 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 86134 ARTIST : Gigi D'Agostino
# 86159 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 86212 ARTIST : Tool
# 86225 ARTIST : American Hi
# 86250 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 86268 ARTIST : Sugar Ray
# 86348 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 86390 ARTIST : Eve 6
# 86402 ARTIST : The Wiseguys
# 86404 ARTIST : Willa Ford
# 86410 ARTIST : Afroman
# 86446 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 86449 ARTIST : Cyndi Thomson
# 86489 ARTIST : Black Rob
# 86489 ARTIST : Mark Curry
# 86499 ARTIST : Pack Summer
# Not actually a spotify artist!
# 86501 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 86503 ARTIST : Public Announcement
# 86555 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 86581 ARTIST : Pack Summer
# Not actually a spotify artist!
# 86587 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 86594 ARTIST : Lil' Wayne
# 86657 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 86673 ARTIST : Pack Summer
# Not actually a spotify artist!
# 86674 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 86687 ARTIST : Coo Coo Cal
# 86741 ARTIST : Pack Summer
# Not actually a spotify artist!
# 86746 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 86772 ARTIST : Dream
# 86776 ARTIST : Darude
# 86779 ARTIST : Jimmy Cozier
# 86829 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 86836 ARTIST : Pack Summer
# Not actually a spotify artist!
# 86909 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 86933 ARTIST : Pack Summer
# Not actually a spotify artist!
# 86992 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87039 ARTIST : Pack Summer
# Not actually a spotify artist!
# 87076 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87133 ARTIST : Pack Summer
# Not actually a spotify artist!
# 87161 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87227 ARTIST : Pack Summer
# Not actually a spotify artist!
# 87244 ARTIST : Azul Azul
# 87246 ARTIST : Dante Thomas
# 87248 ARTIST : Lil' Romeo
# 87250 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87322 ARTIST : Pack Summer
# Not actually a spotify artist!
# 87343 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87441 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87514 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87523 ARTIST : St. Lunatics
# 87536 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87591 ARTIST : Sunshine Anderson
# 87601 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87626 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87677 ARTIST : S Club 7
# 87683 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87700 ARTIST : 3LW
# 87703 ARTIST : QB Finest
# 87720 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87753 ARTIST : Moby
# 87754 ARTIST : Case
# 87768 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87802 ARTIST : Sarina Paris
# 87820 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87835 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87891 ARTIST : Eden's Crush
# Not actually a spotify artist!
# 87893 ARTIST : Mark McGuinn
# 87912 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87913 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 87978 ARTIST : Eden's Crush
# Not actually a spotify artist!
# 87997 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 88027 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 88049 ARTIST : Eden's Crush
# Not actually a spotify artist!
# 88073 ARTIST : Amanda
# 88077 ARTIST : Vertical Horizon
# 88083 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 88124 ARTIST : Crazy Town
# 88127 ARTIST : Aerosmith
# 88135 ARTIST : Eden's Crush
# Not actually a spotify artist!
# 88137 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 88144 ARTIST : Jessica Andrews
# 88153 ARTIST : The Corrs
# 88166 ARTIST : ATC
# 88172 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 88219 ARTIST : Eden's Crush
# Not actually a spotify artist!
# 88262 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 88298 ARTIST : Eden's Crush
# Not actually a spotify artist!
# 88300 ARTIST : K
# 88347 ARTIST : Koffee Brown
# 88349 ARTIST : Tim Rushlow
# 88353 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 88391 ARTIST : Eden's Crush
# Not actually a spotify artist!
# 88439 ARTIST : Project Pat
# 88441 ARTIST : Jon B
# 88445 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 88474 ARTIST : Eden's Crush
# Not actually a spotify artist!
# 88532 ARTIST : Modjo
# 88538 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 88562 ARTIST : Eden's Crush
# Not actually a spotify artist!
# 88629 ARTIST : Aaron Carter
# 88631 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 88639 ARTIST : Eden's Crush
# Not actually a spotify artist!
# 88686 ARTIST : Mystikal
# 88720 ARTIST : Bilal
# 88723 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 88728 ARTIST : Eden's Crush
# Not actually a spotify artist!
# 88808 ARTIST : 98 Degrees
# 88810 ARTIST : Dave Hollister
# 88827 ARTIST : Eden's Crush
# Not actually a spotify artist!
# 88908 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 88912 ARTIST : Eden's Crush
# Not actually a spotify artist!
# 88931 ARTIST : Evan And Jaron
# 88994 ARTIST : Carl Thomas
# 89001 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 89002 ARTIST : Eden's Crush
# Not actually a spotify artist!
# 89082 ARTIST : David Gray
# 89084 ARTIST : Philly's Most Wanted
# Not actually a spotify artist!
# 89098 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 89173 ARTIST : Philly's Most Wanted
# Not actually a spotify artist!
# 89212 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 89264 ARTIST : Philly's Most Wanted
# Not actually a spotify artist!
# 89349 ARTIST : Cash Money Millionaires
# 89351 ARTIST : Mikaila
# 89353 ARTIST : Mos Def
# 89353 ARTIST : Pharoahe Monch
# 89354 ARTIST : Philly's Most Wanted
# Not actually a spotify artist!
# 89355 ARTIST : Cha Slide
# 89444 ARTIST : Philly's Most Wanted
# Not actually a spotify artist!
# 89666 ARTIST : Debelah Morgan
# 89742 ARTIST : Samantha Mumba
# 89792 ARTIST : The Clark Family Experience
# 89793 ARTIST : Kelly Price
# 89795 ARTIST : Billy Gilman
# 89877 ARTIST : The Clark Family Experience
# 89890 ARTIST : Profyle
# 89891 ARTIST : Vitamin C
# 89965 ARTIST : The Clark Family Experience
# 89973 ARTIST : Vince Gill
# 89981 ARTIST : Boyz II Men
# 89984 ARTIST : A*Teens
# 90023 ARTIST : Kandi
# 90060 ARTIST : The Clark Family Experience
# 90115 ARTIST : NewSong
# 90153 ARTIST : The Clark Family Experience
# 90158 ARTIST : Yolanda Adams
# 90167 ARTIST : Sunday
# 90169 ARTIST : De La Soul
# 90245 ARTIST : The Clark Family Experience
# 90263 ARTIST : Nine Days
# 90336 ARTIST : The Clark Family Experience
# 90354 ARTIST : Chante Moore
# 90396 ARTIST : Sisqo
# 90400 ARTIST : SoulDecision
# Not actually a spotify artist!
# 90427 ARTIST : The Clark Family Experience
# 90438 ARTIST : Cam'ron
# 90444 ARTIST : Shyne
# 90485 ARTIST : SoulDecision
# Not actually a spotify artist!
# 90527 ARTIST : The Clark Family Experience
# 90532 ARTIST : Changing Faces
# 90569 ARTIST : SoulDecision
# Not actually a spotify artist!
# 90609 ARTIST : The Clark Family Experience
# 90611 ARTIST : Baha Men
# 90622 ARTIST : The Wallflowers
# 90654 ARTIST : SoulDecision
# Not actually a spotify artist!
# 90665 ARTIST : Everclear
# 90703 ARTIST : The Clark Family Experience
# 90712 ARTIST : Sister Hazel
# 90744 ARTIST : SoulDecision
# Not actually a spotify artist!
# 90793 ARTIST : The Clark Family Experience
# 90798 ARTIST : Third Eye Blind
# 90801 ARTIST : Madison Avenue
# 90831 ARTIST : SoulDecision
# Not actually a spotify artist!
# 90925 ARTIST : SoulDecision
# Not actually a spotify artist!
# 90975 ARTIST : Don Henley
# 91012 ARTIST : SoulDecision
# Not actually a spotify artist!
# 91080 ARTIST : Fragma
# 91108 ARTIST : SoulDecision
# Not actually a spotify artist!
# 91201 ARTIST : SoulDecision
# Not actually a spotify artist!
# 91204 ARTIST : Next
# 91237 ARTIST : Da Brat
# 91290 ARTIST : SoulDecision
# Not actually a spotify artist!
# 91350 ARTIST : Ideal
# 91359 ARTIST : Mandy Moore
# 91384 ARTIST : SoulDecision
# Not actually a spotify artist!
# 91392 ARTIST : Son By Four
# 91449 ARTIST : Lara Fabian
# 91451 ARTIST : Stone Temple Pilots
# 91477 ARTIST : SoulDecision
# Not actually a spotify artist!
# 91538 ARTIST : Lucy Pearl
# 91545 ARTIST : Lil' Mo
# 91564 ARTIST : SoulDecision
# Not actually a spotify artist!
# 91635 ARTIST : Gerald Levert
# 91659 ARTIST : SoulDecision
# Not actually a spotify artist!
# 91721 ARTIST : Eric Heatherly
# 91731 ARTIST : Zombie Nation
# 91752 ARTIST : SoulDecision
# Not actually a spotify artist!
# 91849 ARTIST : SoulDecision
# Not actually a spotify artist!
# 91917 ARTIST : Splender
# 91951 ARTIST : SoulDecision
# Not actually a spotify artist!
# 91959 ARTIST : Macy Gray
# 91971 ARTIST : Chad Brock
# 91997 ARTIST : Alice Deejay
# 91998 ARTIST : Savage Garden
# 92053 ARTIST : SoulDecision
# Not actually a spotify artist!
# 92065 ARTIST : Westlife
# 92097 ARTIST : Deborah Cox
# 92102 ARTIST : 504 Boyz
# 92160 ARTIST : SoulDecision
# Not actually a spotify artist!
# 92186 ARTIST : Clay Davidson
# 92199 ARTIST : Torrey Carter
# Not actually a spotify artist!
# 92244 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 92261 ARTIST : SoulDecision
# Not actually a spotify artist!
# 92283 ARTIST : Torrey Carter
# Not actually a spotify artist!
# 92285 ARTIST : Collin Raye
# 92292 ARTIST : M2M
# 92293 ARTIST : Nu Flavor
# 92294 ARTIST : Elton John
# 92295 ARTIST : Big Punisher
# 92335 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 92373 ARTIST : SoulDecision
# Not actually a spotify artist!
# 92381 ARTIST : Torrey Carter
# Not actually a spotify artist!
# 92383 ARTIST : Alison Krauss
# 92425 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 92478 ARTIST : SoulDecision
# Not actually a spotify artist!
# 92479 ARTIST : Torrey Carter
# Not actually a spotify artist!
# 92487 ARTIST : Before Dark
# 92518 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 92570 ARTIST : Torrey Carter
# Not actually a spotify artist!
# 92577 ARTIST : SoulDecision
# Not actually a spotify artist!
# 92579 ARTIST : NAS
# 92582 ARTIST : En Vogue
# 92603 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 92628 ARTIST : Sonique
# 92667 ARTIST : Torrey Carter
# Not actually a spotify artist!
# 92677 ARTIST : Steve Wariner
# 92698 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 92767 ARTIST : Torrey Carter
# Not actually a spotify artist!
# 92789 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 92862 ARTIST : Yankee Grey
# 92864 ARTIST : Anastacia
# 92880 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 92940 ARTIST : Gloria Estefan
# 92950 ARTIST : Sammie
# 92972 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 93052 ARTIST : Bloodhound Gang
# 93063 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 93093 ARTIST : Montell Jordan
# 93152 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 93234 ARTIST : Ty Herndon
# 93237 ARTIST : Hoku
# 93242 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 93324 ARTIST : D'Angelo
# 93330 ARTIST : Hot Boys
# 93334 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 93368 ARTIST : Blaque
# 93421 ARTIST : Drama
# 93423 ARTIST : Chely Wright
# 93425 ARTIST : Kumbia Kings
# 93429 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 93522 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 93603 ARTIST : Eiffel 65
# 93616 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 93802 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 93894 ARTIST : arranged
# 93895 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 93975 ARTIST : R.L.
# 93981 ARTIST : Robbie Williams
# 93987 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 94065 ARTIST : Kevon Edmonds
# 94071 ARTIST : Bon
# 94074 ARTIST : Mint Condition
# 94075 ARTIST : Amel Larrieux
# 94076 ARTIST : Tracie Spencer
# 94091 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 94169 ARTIST : Rage Against The Machine
# 94185 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 94223 ARTIST : Ol' Dirty Bastard
# 94279 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 94350 ARTIST : Guy
# 94370 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 94428 ARTIST : IMx
# 94463 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 94493 ARTIST : 702
# 94529 ARTIST : Lou Bega
# 94535 ARTIST : Bush
# 94536 ARTIST : Sole
# 94539 ARTIST : Beth Hart
# 94555 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 94629 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 94644 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 94669 ARTIST : Len
# 94720 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 94739 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 94785 ARTIST : Kenny G
# 94803 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 94808 ARTIST : Fatboy Slim
# 94847 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 94883 ARTIST : Marc Nelson
# 94890 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 94896 ARTIST : Chico DeBarge
# 94943 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 94981 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95043 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95057 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95126 ARTIST : Tal Bachman
# 95147 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95157 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95166 ARTIST : Warren G
# 95238 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95323 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95405 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95444 ARTIST : Please
# 95481 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95491 ARTIST : Eric Benet
# 95528 ARTIST : Melissa Etheridge
# 95571 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95658 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95689 ARTIST : Fastball
# 95718 ARTIST : EVE
# 95718 ARTIST : Nokio
# 95719 ARTIST : Silk
# 95754 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95798 ARTIST : Edwin McCain
# 95844 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95864 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95893 ARTIST : Lil' Troy
# 95935 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95938 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 95980 ARTIST : Naughty By Nature
# 96019 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96024 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96071 ARTIST : Youngstown
# 96074 ARTIST : Lauryn Hill
# 96100 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96118 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96127 ARTIST : Citizen King
# 96154 ARTIST : Alabama
# 96162 ARTIST : Joey McIntyre
# 96163 ARTIST : Coko
# 96185 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96224 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96252 ARTIST : Sherrie Austin
# 96267 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96329 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96349 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96414 ARTIST : Byes
# 96426 ARTIST : Donna Summer
# 96427 ARTIST : Tori Amos
# 96435 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96513 ARTIST : The Beatnuts
# 96520 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96576 ARTIST : Lit
# 96600 ARTIST : JT Money
# 96604 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96681 ARTIST : Mary Chapin Carpenter
# 96688 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96768 ARTIST : T.W.D.Y.
# 96770 ARTIST : B*Witched
# 96771 ARTIST : Mercedes
# 96774 ARTIST : Terry Dexter
# 96775 ARTIST : Dwight Yoakam
# 96778 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96857 ARTIST : Jordan Knight
# 96866 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96947 ARTIST : Lila McCann
# 96955 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 96996 ARTIST : Everlast
# 97043 ARTIST : Shane Minor
# 97044 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 97134 ARTIST : Destiny's Child
# Not actually a spotify artist!
# 97221 ARTIST : Collective Soul

# %% [markdown]
# # Attaining Spotify's Audio Features

# %%
def trackInfo(albums, artist):
    albumData = pd.DataFrame(columns = ['Artist', 'Album','Name', 'Popularity', 'Duration', 'Explicit', 'Danceability', 'Energy', 'Loudness', 'Mode', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo', 'TimeSignature'])
    for album in albums:
        albumId = album['id']
        albumName = album['name']
        tracks = sp.album_tracks(albumId)['items']
        for track in tracks:
            trackName = track['name']
            features = sp.audio_features(track['uri'])
            #to get popularity and explicit
            trackInfo = sp.track(track['uri'])
            #Create DF row     ###Maybe try to change duration to be in seconds
            albumData = albumData.append({'Artist':artist, 'Album':albumName,'Name':trackName, 'Popularity':trackInfo['popularity'], 'Duration':features[0]['duration_ms'], 'Explicit':trackInfo['explicit'], 'Danceability':features[0]['danceability'], 'Energy':features[0]['energy'], 'Loudness':features[0]['loudness'], 'Mode':features[0]['mode'], 'Speechiness':features[0]['speechiness'], 'Acousticness':features[0]['acousticness'], 'Instrumentalness':features[0]['instrumentalness'], 'Liveness':features[0]['liveness'], 'Valence':features[0]['valence'], 'Tempo':features[0]['tempo'], 'TimeSignature':features[0]['time_signature']}, ignore_index = True)
    return albumData

# %%
trackInfo(albs, 'twenty one pilots')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-e00004626728> in <module>
# ----> 1 trackInfo(albs, 'twenty one pilots')
#
# <ipython-input-17-26b4187376b2> in trackInfo(albums, artist)
#       9             features = sp.audio_features(track['uri'])
#      10             #to get popularity and explicit
# ---> 11             trackInfo = sp.track(track['uri'])
#      12             #Create DF row     ###Maybe try to change duration to be in seconds
#      13             albumData = albumData.append({'Artist':artist, 'Album':albumName,'Name':trackName, 'Popularity':trackInfo['popularity'], 'Duration':features[0]['duration_ms'], 'Explicit':trackInfo['explicit'], 'Danceability':features[0]['danceability'], 'Energy':features[0]['energy'], 'Loudness':features[0]['loudness'], 'Mode':features[0]['mode'], 'Speechiness':features[0]['speechiness'], 'Acousticness':features[0]['acousticness'], 'Instrumentalness':features[0]['instrumentalness'], 'Liveness':features[0]['liveness'], 'Valence':features[0]['valence'], 'Tempo':features[0]['tempo'], 'TimeSignature':features[0]['time_signature']}, ignore_index = True)
#
# //anaconda3/lib/python3.7/site-packages/spotipy/client.py in track(self, track_id)
#     221
#     222         trid = self._get_id('track', track_id)
# --> 223         return self._get('tracks/' + trid)
#     224
#     225     def tracks(self, tracks, market = None):
#
# //anaconda3/lib/python3.7/site-packages/spotipy/client.py in _get(self, url, args, payload, **kwargs)
#     144         while retries > 0:
#     145             try:
# --> 146                 return self._internal_call('GET', url, payload, kwargs)
#     147             except SpotifyException as e:
#     148                 retries -= 1
#
# //anaconda3/lib/python3.7/site-packages/spotipy/client.py in _internal_call(self, method, url, payload, params)
#     106         if self.trace_out:
#     107             print(url)
# --> 108         r = self._session.request(method, url, headers=headers, proxies=self.proxies, **args)
#     109
#     110         if self.trace:  # pragma: no cover
#
# //anaconda3/lib/python3.7/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# //anaconda3/lib/python3.7/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# //anaconda3/lib/python3.7/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     341         # Trigger any extra validation we need to do.
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#     345             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     837         # Force connect early to allow us to validate the connection.
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#     841         if not conn.is_verified:
#
# //anaconda3/lib/python3.7/site-packages/urllib3/connection.py in connect(self)
#     342             ca_cert_dir=self.ca_cert_dir,
#     343             server_hostname=server_hostname,
# --> 344             ssl_context=context)
#     345
#     346         if self.assert_fingerprint:
#
# //anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     345             or IS_SECURETRANSPORT):
#     346         if HAS_SNI and server_hostname is not None:
# --> 347             return context.wrap_socket(sock, server_hostname=server_hostname)
#     348
#     349         warnings.warn(
#
# //anaconda3/lib/python3.7/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     454         while True:
#     455             try:
# --> 456                 cnx.do_handshake()
#     457             except OpenSSL.SSL.WantReadError:
#     458                 if not util.wait_for_read(sock, sock.gettimeout()):
#
# //anaconda3/lib/python3.7/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1912         :return: None.
#    1913         """
# -> 1914         result = _lib.SSL_do_handshake(self._ssl)
#    1915         self._raise_ssl_error(self._ssl, result)
#    1916
#
# KeyboardInterrupt:

# %% [markdown]
# ## Write the Files For Archetype Artists

# %%
def archetypeContentInfo(artistList):
    df = pd.DataFrame(columns = ['Artist', 'Album','Track', 'Popularity', 'Explicit', 'Danceability', 'Energy', 'Loudness', 'Mode', 'Speechiness', 'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo', 'Duration', 'TimeSignature'])
    for artist in artistList:
        followers, genres = spotifyArtistInfo(artist)
        albums, firstYear = spotifyArtistAblums(artist)
        data = trackInfo(albums, artist)
        df = pd.concat([data, df])
    df.to_csv("FrostData/songAttributes.csv")

# %%
artistList = ["Maroon 5", "Taylor Swift", "Foo Fighters", "J Cole", "Justin Bieber", "Britney Spears", "Justin Timberlake", "Twenty One Pilots", "Elton John", "Beatles", "Khalid", "Billie Eilish"]
archetypeContentInfo(artistList)
