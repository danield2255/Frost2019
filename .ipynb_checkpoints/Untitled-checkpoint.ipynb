# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("FrostData/billboardDataClean.csv", index_col = "Artists")

# %%
sub = df.loc[["Justin Timberlake"]]
sub
#sub[sub["Name"].str.contains("hat")]
# Out:
#                        X                     Name  BillboardWeekRank  \
# Artists
# Justin Timberlake   5758            Say Something                100
# Justin Timberlake   5844            Say Something                 88
# Justin Timberlake   5932            Say Something                 78
# Justin Timberlake   6015            Say Something                 65
# Justin Timberlake   6089            Say Something                 41
# Justin Timberlake   6189            Say Something                 42
# Justin Timberlake   6283            Say Something                 37
# Justin Timberlake   6379            Say Something                 33
# Justin Timberlake   6476            Say Something                 32
# Justin Timberlake   6569            Say Something                 26
# Justin Timberlake   6674            Say Something                 32
# Justin Timberlake   6770            Say Something                 29
# ...
